# %%
import json
import sys
import os
import requests
import warnings

# Add the project root to the Python path
project_root = os.path.abspath(os.path.join(os.path.dirname(__file__), '..', '..'))
sys.path.append(project_root)

from src.utils.helper import load_env
from collections import Counter
from sentence_transformers import SentenceTransformer, util
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load environment variables and API keys
warnings.filterwarnings('ignore')
load_env()
ANTHROPIC_API_KEY = os.getenv("ANTHROPIC_API_KEY")
CLIENT_SECRET = os.getenv("WPCOM_CLIENT_SECRET")
ACCESS_TOKEN = os.getenv("WPCOM_ACCESS_TOKEN")
# Out:
# Found .env file at: /Users/firatgelbal/code/misc/a8c-data-blog/.env
# load_dotenv() result: True

# %%
# Define WordPress.com API constants
AUTHORIZATION_BASE_URL = 'https://public-api.wordpress.com/oauth2/authorize'
TOKEN_URL = 'https://public-api.wordpress.com/oauth2/token
CLIENT_ID = <CLIENT_ID>
REDIRECT_URI = <REDIRECT_URI>

site_url = "data.blog"

# %%
def get_posts(site_url, access_token, page_size=100, max_posts=1000):
    api_url = f"https://public-api.wordpress.com/rest/v1.1/sites/{site_url}/posts"

    headers = {
        "Authorization": f"Bearer {access_token}"
    }

    params = {
        "fields": "ID,title,content,categories,tags,URL,excerpt",
        "number": page_size,
        "page": 1
    }

    all_posts = []
    total_posts_checked = 0

    while True:
        try:
            response = requests.get(api_url, headers=headers, params=params)
            response.raise_for_status()

            data = response.json()
            posts = data.get('posts', [])

            if not posts:
                break  # No more posts to process

            for post in posts:
                total_posts_checked += 1
                all_posts.append({
                    'ID': post['ID'],
                    'title': post['title'],
                    'URL': post['URL'],
                    'content': post['content'],
                    'tags': post['tags'],
                    'categories': post['categories'],
                })

            if total_posts_checked >= max_posts:
                break  # Reached the maximum number of posts to check

            params['page'] += 1  # Move to the next page

        except requests.exceptions.RequestException as e:
            print(f"An error occurred: {e}")
            break

    return all_posts

# %%
# Helper functions for data handling
def extract_names(metadata_dict):
    """
    Extracts the names of tags or categories from the metadata dictionary
    returned by the WordPress.com API.

    :param metadata_dict: Dictionary containing tag or category metadata
    :return: List of tag or category names
    """
    return list(metadata_dict.keys())

def load_posts(file_name='posts.json'):
    file_path = os.path.join('..', '..', 'data', file_name)
    with open(file_path, 'r') as f:
        return json.load(f)

def save_posts(posts, file_name='updated_posts.json'):
    file_path = os.path.join('..', '..', 'data', file_name)
    with open(file_path, 'w') as f:
        json.dump(posts, f, indent=2)

def get_sentence_transformer(model_name='all-MiniLM-L6-v2', cache_dir='./model_cache'):
   os.makedirs(cache_dir, exist_ok=True)
   cache_path = os.path.join(cache_dir, model_name.replace('/', '_'))

   if os.path.exists(cache_path):
       print(f"Loading model from cache: {cache_path}")
       model = SentenceTransformer(cache_path)
   else:
       print(f"Downloading and caching model: {model_name}")
       model = SentenceTransformer(model_name)
       model.save(cache_path)

   return model

# %%
posts = get_posts(site_url, ACCESS_TOKEN)

# %%
existing_categories = []
existing_tags = []
for post in posts:
    for category in post['categories']:
        if category not in existing_categories:
            existing_categories.append(category)
    for tag in post['tags']:
        if tag not in existing_tags:
            existing_tags.append(tag)

# %%
def find_similar_tags(tags, threshold=0.7):
    if not tags:
        return {}

    # Create TF-IDF vectors for tags
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(tags)

    # Compute cosine similarity
    cosine_similarities = cosine_similarity(tfidf_matrix, tfidf_matrix)

    similar_tags = {}
    for i, tag in enumerate(tags):
        similar = [(tags[j], cosine_similarities[i][j])
                   for j in range(len(tags))
                   if i != j and cosine_similarities[i][j] > threshold]
        if similar:
            similar_tags[tag] = similar

    return similar_tags

# %%
similar_tags = find_similar_tags(existing_tags)
similar_tags
# Out:
# {'Data Science': [('science', 0.7915145702180151)],
#  'data analytics': [('analytics', 0.8251239666050941)],
#  'machine learning': [('machine learning models', 0.7840102790432525)],
#  'analytics': [('data analytics', 0.8251239666050941)],
#  'a/b testing': [('testing bias', 0.7071067811865476)],
#  'marketing': [('marketing science', 0.7482020483410375)],
#  'marketing science': [('marketing', 0.7482020483410375)],
#  'bias': [('testing bias', 0.7071067811865476)],
#  'gender bias': [('gender', 0.7424392663387555)],
#  'data ethics': [('ethics', 0.8395851060963966)],
#  'ethics': [('data ethics', 0.8395851060963966)],
#  'testing bias': [('a/b testing', 0.7071067811865476),
#   ('bias', 0.7071067811865476)],
#  'algorithms': [('learning algorithms', 0.7664706291023498)],
#  'analysis': [('data analysis', 0.7915145702180151)],
#  'Deep Learning': [('deep learning architecture', 0.7936814833423467)],
#  'gender': [('gender bias', 0.7424392663387555)],
#  'science': [('Data Science', 0.7915145702180151)],
#  'descriptive data analysis': [('data analysis', 0.700841371855489)],
#  'learning algorithms': [('algorithms', 0.7664706291023498)],
#  'deep learning architecture': [('Deep Learning', 0.7936814833423467)],
#  'machine learning models': [('machine learning', 0.7840102790432525)],
#  'data analysis': [('analysis', 0.7915145702180151),
#   ('descriptive data analysis', 0.700841371855489)]}

# %%
#model = SentenceTransformer('all-MiniLM-L6-v2')
# Cache the model for future re-use
model = get_sentence_transformer()
# Out:
# Loading model from cache: ./model_cache/all-MiniLM-L6-v2

# %%
def suggest_tags_and_categories(post_content, existing_tags, existing_categories):
    # Encode post content
    post_embedding = model.encode(post_content, convert_to_tensor=True)

    # Encode existing tags and categories
    tag_embeddings = model.encode(existing_tags, convert_to_tensor=True)
    category_embeddings = model.encode(existing_categories, convert_to_tensor=True)

    # Compute similarities
    tag_similarities = util.pytorch_cos_sim(post_embedding, tag_embeddings)[0]
    category_similarities = util.pytorch_cos_sim(post_embedding, category_embeddings)[0]

    # Get top 3 tags and top category
    suggested_tags = [existing_tags[i] for i in tag_similarities.argsort(descending=True)[:3]]
    suggested_category = existing_categories[category_similarities.argmax().item()]

    return suggested_tags, suggested_category

# %%
def analyze_posts_and_collect_stats(posts, existing_tags, existing_categories, filter_tags=None, serialize=False):
    if filter_tags is None:
        filter_tags = ['Automattic', 'code', 'data', 'Google', 'charts']

    suggested_tag_stats = Counter()
    suggested_category_stats = Counter()
    posts_analyzed = 0
    posts_with_new_suggestions = set()  # Use a set to count unique posts

    # Serialize existing tags and categories
    original_taxonomy = []

    for post in posts:
        posts_analyzed += 1
        print(f"\nAnalyzing post: {post['title']}")

        # Extract current tags and categories
        current_tags = extract_names(post['tags'])
        current_category = extract_names(post['categories'])[0] if post['categories'] else None

        # Serialize original taxonomy
        original_taxonomy.append({
            'ID': post['ID'],
            'title': post['title'],
            'URL': post['URL'],
            'tags': current_tags,
            'category': current_category
        })

        # Suggest tags and categories
        suggested_tags, suggested_category = suggest_tags_and_categories(
            post['content'], existing_tags, existing_categories
        )

        # Filter out specific tags
        suggested_tags = [tag for tag in suggested_tags if tag not in filter_tags]

        # Add suggested tags and category to the post object
        post['suggested_tags'] = suggested_tags
        post['suggested_category'] = suggested_category

        # Determine if post needs update
        new_tag_suggestions = set(suggested_tags) - set(current_tags)
        category_changed = suggested_category != current_category
        post['needs_update'] = bool(new_tag_suggestions or category_changed)

        # Collect stats for suggested tags
        if new_tag_suggestions:
            posts_with_new_suggestions.add(post['ID'])
            for tag in new_tag_suggestions:
                suggested_tag_stats[tag] += 1

        # Collect stats for suggested category
        if category_changed:
            posts_with_new_suggestions.add(post['ID'])
            suggested_category_stats[suggested_category] += 1

        print(f"Current tags: {current_tags}")
        print(f"Suggested tags: {suggested_tags}")
        print(f"Current category: {current_category}")
        print(f"Suggested category: {suggested_category}")
        print(f"Needs update: {post['needs_update']}")

    if serialize:
        # Serialize original taxonomy
        with open('original_taxonomy.json', 'w') as f:
            json.dump(original_taxonomy, f, indent=2)

    return {
        'suggested_tag_stats': suggested_tag_stats,
        'suggested_category_stats': suggested_category_stats,
        'posts_analyzed': posts_analyzed,
        'posts_with_new_suggestions': len(posts_with_new_suggestions)
    }

def print_taxonomy_stats(stats):
    print("\n--- Taxonomy Suggestion Statistics ---")
    print(f"Total posts analyzed: {stats['posts_analyzed']}")
    print(f"Unique posts with new suggestions: {stats['posts_with_new_suggestions']}")

    print("\nTop 10 Suggested Tags:")
    for tag, count in stats['suggested_tag_stats'].most_common(10):
        print(f"  {tag}: {count} posts")

    print("\nSuggested Categories:")
    for category, count in stats['suggested_category_stats'].most_common():
        print(f"  {category}: {count} posts")

def suggest_taxonomy_improvements(stats, existing_tags, existing_categories, tag_threshold=5, max_tags=50, max_categories=10):
    print("\n--- Suggested Taxonomy Improvements ---")

    # Suggest new tags to add
    new_tags = [tag for tag, count in stats['suggested_tag_stats'].items() if count >= tag_threshold and tag not in existing_tags]
    if new_tags:
        print(f"\nSuggested new tags to add (appeared in at least {tag_threshold} posts):")
        for tag in new_tags[:max_tags - len(existing_tags)]:
            print(f"  {tag}: {stats['suggested_tag_stats'][tag]} posts")

    # Suggest tags to remove (not suggested for any posts)
    unused_tags = set(existing_tags) - set(stats['suggested_tag_stats'].keys())
    if unused_tags:
        print("\nTags that were never suggested (consider removing):")
        for tag in unused_tags:
            print(f"  {tag}")

    # Suggest category changes
    if len(stats['suggested_category_stats']) > len(existing_categories):
        print("\nSuggested category changes:")
        for category, count in stats['suggested_category_stats'].most_common(max_categories):
            if category not in existing_categories:
                print(f"  Consider adding: {category} (suggested for {count} posts)")

    # Overall recommendations
    print("\nOverall recommendations:")
    if len(existing_tags) + len(new_tags) > max_tags:
        print(f"  - Consider limiting the total number of tags to {max_tags}")
    if len(stats['suggested_category_stats']) > max_categories:
        print(f"  - Consider limiting the total number of categories to {max_categories}")

# %%
filter_tags = ['Automattic', 'code', 'data', 'Google', 'charts']
stats = analyze_posts_and_collect_stats(posts, existing_tags, existing_categories, filter_tags)
print_taxonomy_stats(stats)
# Out:
# Analyzing post: Data Talks &amp; Conferences Recommended by Automatticians
# Current tags: ['Data careers', 'Data Science', 'distributed work', 'remote work']
# Suggested tags: ['conference', 'Data careers']
# Current category: Data at Automattic
# Suggested category: Data at Automattic
# Needs update: True
#
# Analyzing post: What your neurodivergent colleagues wish you knew
# Current tags: ['distributed work', 'remote work']
# Suggested tags: ['diversity', 'demographic targeting', 'imposter syndrome']
# Current category: Interview
# Suggested category: Network Science
# Needs update: True
#
# Analyzing post: From Support to Data Science and Analytics: My Journey at Automattic
# Current tags: ['data analytics', 'Data careers', 'Data Engineering', 'Data Science', 'tech']
# Suggested tags: ['Data careers', 'data scientist', 'support']
# Current category: Data at Automattic
# Suggested category: Data Engineering
# Needs update: True
#
# Analyzing post: Hack Project: Creating a tool to translate customer feedback into product insights
# Current tags: ['artificial intelligence', 'Data Science', 'Data Visualization', 'distributed work', 'meetup']
# Suggested tags: ['automation', 'teamwork']
# Current category: Data at Automattic
# Suggested category: Distributed Work
# Needs update: True
#
# Analyzing post: Hack Project: Tackling FOMO on the P2 Land
# Current tags: ['communication', 'distributed work', 'machine learning', 'productivity', 'remote work']
# Suggested tags: ['blogging', 'distributed work', 'automation']
# Current category: Data at Automattic
# Suggested category: Distributed Work
# Needs update: True
#
# Analyzing post: Optimizing Connections at Meetups
# Current tags: ['distributed work', 'meetup', 'social science']
# Suggested tags: ['meetup', 'distributed work', 'teamwork']
# Current category: Data at Automattic
# Suggested category: Distributed Work
# Needs update: True
#
# Analyzing post: Synchronizing Data with Apache Superset: Our Internal Solution
# Current tags: ['tooling']
# Suggested tags: ['automation', 'Data Engineering', 'Data Discoverability']
# Current category: Data at Automattic
# Suggested category: Data at Automattic
# Needs update: True
#
# Analyzing post: The New Face of Jetpack Stats
# Current tags: ['distributed work', 'Jetpack', 'remote work']
# Suggested tags: ['analytics', 'Jetpack', 'hr analytics']
# Current category: Data Visualization
# Suggested category: Data Engineering
# Needs update: True
#
# Analyzing post: Quest for Efficient AI: An Evaluation of the Vector Database Landscape
# Current tags: ['artificial intelligence', 'Automattic', 'Semantic Search']
# Suggested tags: ['Semantic Search', 'word embeddings', 'information retrieval']
# Current category: Data at Automattic
# Suggested category: Search
# Needs update: True
#
# Analyzing post: Visualizing Diversity at Automattic
# Current tags: ['diversity']
# Suggested tags: ['diversity', 'Adversarial Image Classification', 'transparency']
# Current category: Data Visualization
# Suggested category: Data Visualization
# Needs update: True
#
# Analyzing post: Tips for a healthy work-life balance for people starting at a remote company
# Current tags: ['distributed work', 'remote work', 'work life balance']
# Suggested tags: ['distributed work', 'remote work', 'work life balance']
# Current category: Distributed Work
# Suggested category: Distributed Work
# Needs update: False
#
# Analyzing post: How to Organize a Data Book Club at Work
# Current tags: ['Book Club', 'books', 'distributed work', 'learning']
# Suggested tags: ['learning', 'books']
# Current category: Reading
# Suggested category: Reading
# Needs update: False
#
# Analyzing post: Women of Datamattic | Menaka Sankaralingam
# Current tags: ['Data careers', 'distributed work', 'work life balance']
# Suggested tags: ['Data careers', 'data products', 'data scientist']
# Current category: Data at Automattic
# Suggested category: Data at Automattic
# Needs update: True
#
# Analyzing post: Women of Datamattic: Madison Swain-Bowden
# Current tags: ['Data careers', 'work life balance']
# Suggested tags: ['data ethics', 'this week in data reading']
# Current category: Data at Automattic
# Suggested category: Data Visualization
# Needs update: True
#
# Analyzing post: Women of Datamattic: Anna Elek
# Current tags: ['Data careers', 'work life balance']
# Suggested tags: ['data scientist', 'Data careers', 'Data Engineering']
# Current category: Data at Automattic
# Suggested category: Data at Automattic
# Needs update: True
#
# Analyzing post: The Data Docs: A WordPress based Data Discoverability Tool
# Current tags: ['API', 'Data Discoverability', 'P2', 'tooling', 'WordPress']
# Suggested tags: ['search engines', 'Semantic Search', 'Data Discoverability']
# Current category: Data at Automattic
# Suggested category: Search
# Needs update: True
#
# Analyzing post: Stocking Stuffers for the Data Team
# Current tags: ['books', 'distributed work', 'remote work']
# Suggested tags: ['productivity', 'Latex', 'euroscipy']
# Current category: Data at Automattic
# Suggested category: Reading
# Needs update: True
#
# Analyzing post: Automattic’s First Data+ Meetup
# Current tags: ['distributed work', 'meetup', 'remote work']
# Suggested tags: ['teamwork', 'Data careers', 'data scientist']
# Current category: Data at Automattic
# Suggested category: Data at Automattic
# Needs update: True
#
# Analyzing post: How to Save Time with Alfred, Stream Deck, and Apple Shortcuts
# Current tags: ['automation', 'distributed work', 'productivity', 'remote work']
# Suggested tags: ['automation', 'work life balance']
# Current category: Data at Automattic
# Suggested category: Data at Automattic
# Needs update: True
#
# Analyzing post: How to profit from an Analytics Skill Matrix
# Current tags: ['data analytics', 'Data careers', 'data scientist', 'distributed work']
# Suggested tags: ['hr analytics', 'analytics', 'Data careers']
# Current category: Data at Automattic
# Suggested category: Data at Automattic
# Needs update: True
#
# Analyzing post: Challenge Hiring Assumptions with Data
# Current tags: []
# Suggested tags: ['testing bias', 'a/b testing', 'experiments']
# Current category: Data at Automattic
# Suggested category: Interview
# Needs update: True
#
# Analyzing post: Advance your Career with Automattic Rotations
# Current tags: ['work life balance']
# Suggested tags: ['automation', 'search engines']
# Current category: Interview
# Suggested category: Data at Automattic
# Needs update: True
#
# Analyzing post: Join us at Tumblr!
# Current tags: ['analytics', 'distributed work', 'elasticsearch', 'machine learning', 'remote work']
# Suggested tags: ['blogging', 'social media', 'social psychology']
# Current category: Data at Automattic
# Suggested category: Distributed Work
# Needs update: True
#
# Analyzing post: ExPlat’s Development Principles and Practices
# Current tags: ['a/b testing', 'Automattic', 'coding conventions', 'software engineering', 'software testing']
# Suggested tags: ['automation', 'distributed work']
# Current category: Experimentation Platform
# Suggested category: Distributed Work
# Needs update: True
#
# Analyzing post: Architecting ExPlat: Automattic’s New Experimentation Platform
# Current tags: ['ab testing', 'Data Science', 'experimentation', 'software architecture', 'software engineering']
# Suggested tags: ['software architecture', 'automation']
# Current category: Data at Automattic
# Suggested category: Data at Automattic
# Needs update: True
#
# Analyzing post: ExPlat: Automattic’s Experimentation Platform
# Current tags: []
# Suggested tags: ['automation', 'open source']
# Current category: Data at Automattic
# Suggested category: Experimentation Platform
# Needs update: True
#
# Analyzing post: Being globally distributed: a constant reminder to have an open mind and more
# Current tags: ['distributed work', 'remote work', 'tech']
# Suggested tags: ['hr analytics', 'Latex', 'remote work']
# Current category: Data at Automattic
# Suggested category: Distributed Work
# Needs update: True
#
# Analyzing post: SQL — a Common Language for the Whole Data Team
# Current tags: []
# Suggested tags: ['data scientist', 'Data Engineering', 'Data careers']
# Current category: Data at Automattic
# Suggested category: Data Engineering
# Needs update: True
#
# Analyzing post: &#8220;I found a lot of new and exciting ways to break WordPress.com&#8221;: Highlights of our time at Automattic
# Current tags: ['analytics', 'distributed work', 'elasticsearch', 'machine learning', 'marketing', 'marketing science', 'remote work', 'tech']
# Suggested tags: ['hr analytics', 'Latex']
# Current category: Data at Automattic
# Suggested category: Interview
# Needs update: True
#
# Analyzing post: One Pandemic, Four Countries and Six Different Stories
# Current tags: ['covid-19', 'digital minimalism', 'distributed work', 'remote work', 'tech', 'work life balance']
# Suggested tags: ['covid-19', 'technology', 'analytics']
# Current category: Data at Automattic
# Suggested category: Distributed Work
# Needs update: True
#
# Analyzing post: Teaching Python to Beginners
# Current tags: ['Python']
# Suggested tags: ['learning', 'Python', 'software engineering']
# Current category: Data at Automattic
# Suggested category: Data Engineering
# Needs update: True
#
# Analyzing post: Five Paths to Automattic
# Current tags: ['data analytics', 'Data careers', 'Data Engineering', 'Data Science', 'distributed work', 'tech']
# Suggested tags: ['Latex']
# Current category: Data at Automattic
# Suggested category: Data at Automattic
# Needs update: True
#
# Analyzing post: Boris Gorelik on the biggest missed opportunity in data visualization
# Current tags: ['Boris Gorelik', 'Data Speaker Series', 'effective communication', 'scientific communication']
# Suggested tags: ['Data Visualization', 'data scientist', 'data exploration']
# Current category: Data Science
# Suggested category: Data Visualization
# Needs update: True
#
# Analyzing post: How to Avoid Statistical Bootstrapping Pitfalls
# Current tags: ['analytics', 'statistics']
# Suggested tags: ['hr analytics', 'blogging', 'search engines']
# Current category: Data Science
# Suggested category: Data Science
# Needs update: True
#
# Analyzing post: Gender and Racial Bias in Cloud NLP Sentiment APIs
# Current tags: ['Amazon', 'bias', 'gender bias', 'Google', 'natural language processing', 'racial bias']
# Suggested tags: ['natural language processing', 'word embeddings', 'Semantic Search']
# Current category: Data Science
# Suggested category: Search
# Needs update: True
#
# Analyzing post: Christo Wilson Discusses the Ethics of Online Behavioral Experiments
# Current tags: ['Christo Wilson', 'data ethics', 'ethics', 'Online Behavioral Experiments']
# Suggested tags: ['Online Behavioral Experiments', 'testing bias', 'experiments']
# Current category: Data Science
# Suggested category: Experimentation Platform
# Needs update: True
#
# Analyzing post: Using ML for Campaign Optimization: Our Journey to Marketing Science at Automattic
# Current tags: ['campaign optimisation', 'marketing science', 'pipe', 'uplift modelling']
# Suggested tags: ['pipe', 'machine learning models', 'machine learning']
# Current category: Data Science
# Suggested category: Data at Automattic
# Needs update: True
#
# Analyzing post: Data Science Insights from Cameron Davidson-Pilon
# Current tags: ['best practices', 'causal inference', 'Data Speaker Series']
# Suggested tags: ['survival analysis', 'Python', 'data scientist']
# Current category: Data Science
# Suggested category: Data Science
# Needs update: True
#
# Analyzing post: This Week in Data Reading: Project Estimation, Abandoning Significance, and Video Games.
# Current tags: ['artificial intelligence', 'statistics']
# Suggested tags: ['missing data', 'this week in data reading']
# Current category: Reading
# Suggested category: Data at Automattic
# Needs update: True
#
# Analyzing post: Looker NYC Meetup
# Current tags: []
# Suggested tags: ['automation', 'data exploration']
# Current category: Data Visualization
# Suggested category: Data at Automattic
# Needs update: True
#
# Analyzing post: This Week in Data Reading: Experimentation, Tech and the Humanities, and Eliminating Bias in Testing
# Current tags: ['experimentation', 'Pinterest', 'technology', 'testing bias', 'the humanities']
# Suggested tags: ['data ethics', 'morality in data']
# Current category: Reading
# Suggested category: Data Visualization
# Needs update: True
#
# Analyzing post: The 2019 Fairness, Accountability, and Transparency Conference
# Current tags: ['accountability', 'artificial intelligence', 'conference', 'fairness', 'justice', 'transparency']
# Suggested tags: ['accountability', 'data ethics', 'demographic targeting']
# Current category: Data Science
# Suggested category: Search
# Needs update: True
#
# Analyzing post: This Week In Data Reading: MOOCs, Collusion in Artificial Intelligence, and Fake News
# Current tags: ['artificial intelligence', 'collusion', 'fake news', 'MOOCs']
# Suggested tags: ['digital anthropology', 'social media']
# Current category: Reading
# Suggested category: Data Science
# Needs update: True
#
# Analyzing post: How to Increase Retention and Revenue in 1,000 Nontrivial Steps
# Current tags: ['marketing', 'pipe', 'retention', 'survival analysis']
# Suggested tags: ['data scientist', 'Data Science', 'Data careers']
# Current category: Data Science
# Suggested category: Data Science
# Needs update: True
#
# Analyzing post: Building Thousands of Reproducible ML Models with pipe, the Automattic Machine Learning Pipeline
# Current tags: ['machine learning', 'pipe']
# Suggested tags: ['pipe', 'automation', 'machine learning models']
# Current category: Data Engineering
# Suggested category: Data at Automattic
# Needs update: True
#
# Analyzing post: Missed Opportunities for Using Text in Data Visualization
# Current tags: ['Richard Brath']
# Suggested tags: ['Data Visualization', 'data scientist', 'data exploration']
# Current category: Data Visualization
# Suggested category: Data Visualization
# Needs update: True
#
# Analyzing post: Links Worth Sharing: What Makes People Successful
# Current tags: ['Albert-László Barabási']
# Suggested tags: ['Albert-László Barabási', 'scientists', 'Network Science']
# Current category: Reading
# Suggested category: Network Science
# Needs update: True
#
# Analyzing post: Introducing pipe, The Automattic Machine Learning Pipeline
# Current tags: ['machine learning', 'marketing', 'models', 'pipe']
# Suggested tags: ['automation', 'pipe']
# Current category: Data Science
# Suggested category: Data at Automattic
# Needs update: True
#
# Analyzing post: Links Worth Sharing: The Training and Security of Neural Networks
# Current tags: ['neural networks', 'security']
# Suggested tags: ['deep learning architecture', 'Deep Learning', 'neural networks']
# Current category: Data Science
# Suggested category: Network Science
# Needs update: True
#
# Analyzing post: The Most Beautiful Social Network: the Structure of Communication at Automattic
# Current tags: ['hr analytics', 'remote work', 'science of work']
# Suggested tags: ['Network Science', 'hr analytics', 'communication']
# Current category: Data Science
# Suggested category: Network Science
# Needs update: True
#
# Analyzing post: Conference Recap: EuroSciPy 2018
# Current tags: ['conference', 'euroscipy', 'open source', 'Python']
# Suggested tags: ['conference', 'YouTube', 'euroscipy']
# Current category: Data Visualization
# Suggested category: Network Science
# Needs update: True
#
# Analyzing post: We&#8217;re Reading About Bandit Algorithms, Binary Classification Problems, and Artificial Intelligence
# Current tags: ['algorithms', 'artificial intelligence', 'binary classification']
# Suggested tags: ['ab testing', 'testing bias', 'Online Behavioral Experiments']
# Current category: Data Science
# Suggested category: Search
# Needs update: True
#
# Analyzing post: Investigating Seasonality in a Time Series: A Mystery in Three Parts
# Current tags: ['analysis', 'seasonality', 'time series']
# Suggested tags: ['seasonality', 'timeseries', 'time series']
# Current category: Data Science
# Suggested category: Data Science
# Needs update: True
#
# Analyzing post: Reflections From Spark + AI Summit 2018
# Current tags: ['heatmaps', 'Java', 'neural networks', 'Python', 'Spark', 'Strava']
# Suggested tags: ['Data Speaker Series', 'conference', 'Deep Learning']
# Current category: Data Science
# Suggested category: Interview
# Needs update: True
#
# Analyzing post: We&#8217;re Reading About AI, Data Visualization, Deep Learning, and More
# Current tags: ['artificial intelligence', 'Data Visualization', 'databases', 'Deep Learning', 'LTSM', 'machine learning', 'neural networks']
# Suggested tags: ['Google Brain', 'artificial intelligence', 'Turing Institute']
# Current category: Reading
# Suggested category: Reading
# Needs update: True
#
# Analyzing post: This Week We&#8217;re Reading the 2018 Stack Overflow Survey
# Current tags: ['bias', 'gender', 'surveys', 'this week in data reading', 'working conditions']
# Suggested tags: ['hr analytics', 'data scientist', 'tech']
# Current category: Data Science
# Suggested category: Network Science
# Needs update: True
#
# Analyzing post: Engineering Data Science at Automattic
# Current tags: ['best practices', 'CircleCI', 'code reviews', 'Conda', 'continuous integration', 'Git', 'Python', 'software engineering']
# Suggested tags: ['data scientist', 'Data Science', 'Data Engineering']
# Current category: Data Science
# Suggested category: Data Science
# Needs update: True
#
# Analyzing post: Data Speaker Series: Kevin Ferguson on AlphaGo Zero
# Current tags: ['artificial intelligence', 'Data Speaker Series', 'Go', 'Kevin Ferguson', 'machine learning']
# Suggested tags: ['learning', 'artificial intelligence', 'Google Brain']
# Current category: Interview
# Suggested category: Network Science
# Needs update: True
#
# Analyzing post: This Week We&#8217;re Reading About Artificial Intelligence and Machine Learning
# Current tags: ['artificial intelligence', 'machine learning', 'particle physics']
# Suggested tags: ['hr analytics', 'information retrieval', 'search engines']
# Current category: Reading
# Suggested category: Search
# Needs update: True
#
# Analyzing post: Analysis of A Beautiful Storm: Internal Communication at Automattic
# Current tags: ['analysis', 'communication', 'interaction', 'remote work', 'science', 'science of work', 'work']
# Suggested tags: ['communication', 'effective communication', 'scientific communication']
# Current category: Data Science
# Suggested category: Network Science
# Needs update: True
#
# Analyzing post: To a Poem is a Bott the Stranger
# Current tags: ['bot', 'experiments', 'neural networks', 'poetry']
# Suggested tags: ['poetry', 'blogging', 'bot']
# Current category: Data Science
# Suggested category: Data Engineering
# Needs update: True
#
# Analyzing post: Do New Year&#8217;s Resolutions Work? Data Suggests They Do!
# Current tags: ['analysis', 'blogging', 'data', "New Year's resolutions", 'science']
# Suggested tags: ['blogging', "New Year's resolutions", 'Facebook']
# Current category: Data Science
# Suggested category: Network Science
# Needs update: True
#
# Analyzing post: We&#8217;re Reading About Artificially Intelligent Harry Potter Fan Fiction, Verifying Online Identities, and More
# Current tags: ['artificial intelligence', 'chess', 'fan fiction', 'Harry Potter', 'math', 'net neutrality', 'replicability crisis', 'social psychology']
# Suggested tags: ['bias', 'heatmaps']
# Current category: Data Science
# Suggested category: Data Visualization
# Needs update: True
#
# Analyzing post: Doing the Math on Key Words and Top Level Domains
# Current tags: ['analysis', 'Latex', 'Top Level Domains']
# Suggested tags: ['Top Level Domains', 'WordPress.org', 'blogging']
# Current category: Data Science
# Suggested category: Network Science
# Needs update: True
#
# Analyzing post: We&#8217;re Reading About Simplifying Without Distortion and Adversarial Image Classification
# Current tags: ['Adversarial Image Classification', 'Ben Orlin', 'Desmond Morris']
# Suggested tags: ['digital anthropology', 'transparency', 'data ethics']
# Current category: Data Science
# Suggested category: Reading
# Needs update: True
#
# Analyzing post: Data Speaker Series: Shaun Lindsay on the Data Science of Marketing
# Current tags: ['data scientist', 'Data Speaker Series', 'guest speaker', 'Honor', 'marketing', 'Shaun Lindsay', 'statistics']
# Suggested tags: ['Adversarial Image Classification']
# Current category: Data Science
# Suggested category: Data Visualization
# Needs update: True
#
# Analyzing post: We&#8217;re Reading About Bias in AI, SpaceX, and More
# Current tags: ['algorithms', 'artificial intelligence', 'Facebook', 'imposter syndrome', 'p-values', 'SpaceX', 'Spotify', 'WaveNet']
# Suggested tags: ['bias', 'heatmaps']
# Current category: Data Science
# Suggested category: Data Visualization
# Needs update: True
#
# Analyzing post: Data Speaker Series: Charles Earl on Discriminatory Artificial Intelligence
# Current tags: ['artificial intelligence', 'Data Speaker Series', 'machine learning']
# Suggested tags: ['bias', 'Data Speaker Series', 'racial bias']
# Current category: Data Science
# Suggested category: Data Science
# Needs update: True
#
# Analyzing post: Easier A/B Tests with Automattic’s Own Tool, Hypotheses
# Current tags: ['ab testing', 'analysis', 'hypotheses-tests', 'statistics']
# Suggested tags: ['a/b testing', 'ab testing', 'software testing']
# Current category: Data Science
# Suggested category: Data at Automattic
# Needs update: True
#
# Analyzing post: This Week in Data Reading (and Watching!)
# Current tags: ['algorithms', 'big data', 'Google Brain', 'machine-made music', 'Magenta', 'morality in data']
# Suggested tags: ['Google Brain', 'deep learning architecture', 'WaveNet']
# Current category: Data Science
# Suggested category: Network Science
# Needs update: True
#
# Analyzing post: Data Speaker Series: Thorsten Dietzsch on Building Data Products at Zalando
# Current tags: ['data products', 'Data Speaker Series', 'product management', 'Thorsten Dietzsch', 'Zalando']
# Suggested tags: ['Data Speaker Series', 'hr analytics', 'learning']
# Current category: Data Science
# Suggested category: Reading
# Needs update: True
#
# Analyzing post: How Communication Density Fuels Automattic
# Current tags: ['hr analytics']
# Suggested tags: ['heatmaps']
# Current category: Data Science
# Suggested category: Data Visualization
# Needs update: True
#
# Analyzing post: This Week in Data Reading
# Current tags: ['artificial intelligence', 'data ethics', 'descriptive data analysis', 'ethics', 'machine learning', 'Turing Institute']
# Suggested tags: ['data ethics', 'data scientist', 'morality in data']
# Current category: Reading
# Suggested category: Data Science
# Needs update: True
#
# Analyzing post: Real-Time Elasticsearch Indexing on WordPress.com
# Current tags: ['databases', 'elasticsearch', 'indexing', 'MySQL', 'WordPress.com']
# Suggested tags: ['elasticsearch', 'indexing', 'search engines']
# Current category: Data Engineering
# Suggested category: Distributed Work
# Needs update: True
#
# Analyzing post: data.coalesce() &#8212; Automattic Data Division Meets in Montréal
# Current tags: ['data', 'learning', 'meetup', 'science', 'scientists']
# Suggested tags: ['hr analytics', 'meetup']
# Current category: Data Science
# Suggested category: Data at Automattic
# Needs update: True
#
# Analyzing post: Time Series Analysis: When “Good Enough” is Good Enough
# Current tags: ['anomaly', 'Data Visualization', 'timeseries']
# Suggested tags: ['Data Engineering', 'Data Discoverability', 'replicability crisis']
# Current category: Data Science
# Suggested category: Data Engineering
# Needs update: True
#
# Analyzing post: This Week in Data Reading
# Current tags: ['algorithm', 'analytics', 'machine learning', 'MySQL', 'pop lyrics']
# Suggested tags: ['word embeddings', 'pop lyrics', 'information retrieval']
# Current category: Data Science
# Suggested category: Reading
# Needs update: True
#
# Analyzing post: May the Bot Be With You: How Algorithms are Supporting Happiness at WordPress.com
# Current tags: ['algorithms', 'bots', 'Happiness Engineering', 'machine learning', 'natural language processing', 'support']
# Suggested tags: ['Happiness Engineering', 'search engines', 'natural language processing']
# Current category: Data Engineering
# Suggested category: Search
# Needs update: True
#
# Analyzing post: This Week in Data Reading (and Watching!)
# Current tags: ['artificial intelligence', 'demographic targeting', 'Facebook', 'learning algorithms', 'Siraj Raval', 'YouTube']
# Suggested tags: ['poetry', 'Google Brain', 'books']
# Current category: Data Science
# Suggested category: Reading
# Needs update: True
#
# Analyzing post: This Week in Data Reading
# Current tags: ['charts', 'graphs', 'tables']
# Suggested tags: ['Data Visualization', 'morality in data']
# Current category: Data Science
# Suggested category: Data Visualization
# Needs update: True
#
# Analyzing post: Welcoming New Colleagues — a Data-Based Story
# Current tags: ['Automattic', 'bonding', 'community analysis', 'distributed work', 'human relationships', 'Network Science', 'social science', 'teamwork']
# Suggested tags: ['distributed work', 'Happiness Engineering', 'teamwork']
# Current category: Data Science
# Suggested category: Distributed Work
# Needs update: True
#
# Analyzing post: This Week in Data Reading
# Current tags: ['digital anthropology', 'Donald Trump', 'natural language processing', 'Reddit']
# Suggested tags: ['word embeddings', 'Latex', 'Google Brain']
# Current category: Data Science
# Suggested category: Reading
# Needs update: True
#
# Analyzing post: Improving Relevance and Elasticsearch Query Patterns
# Current tags: ['elasticsearch', 'plugin repository', 'WordPress.org']
# Suggested tags: ['search engines', 'Semantic Search', 'elasticsearch']
# Current category: Search
# Suggested category: Search
# Needs update: True
#
# Analyzing post: This Week in Data Reading
# Current tags: ['algorithm', 'code', 'deep learning architecture', 'functional programming languages', 'hand-drawn graphics', 'Hans Rosling', 'W.E.B Du Boise']
# Suggested tags: ['Data Visualization', 'Boris Gorelik']
# Current category: Data Visualization
# Suggested category: Data Visualization
# Needs update: True
#
# Analyzing post: How&#8217;s Your New Year&#8217;s Resolution Going?
# Current tags: ['data', 'elasticsearch', "New Year's resolutions"]
# Suggested tags: ["New Year's resolutions", 'this week in data reading', 'surveys']
# Current category: Data Science
# Suggested category: Reading
# Needs update: True
#
# Analyzing post: This Week in Data Reading
# Current tags: ['critical review', 'gender bias', 'graph theory', 'machine learning models', 'natural language processing', 'network analysis', 'open source', 'racial bias', 'telemetry', 'word embeddings']
# Suggested tags: ['the humanities', 'this week in data reading', 'scientists']
# Current category: Data Science
# Suggested category: Reading
# Needs update: True
#
# Analyzing post: Intro to Search: Measurement
# Current tags: ['Data Science', 'information retrieval', 'search engines', 'WordPress']
# Suggested tags: ['search engines', 'information retrieval', 'Semantic Search']
# Current category: Search
# Suggested category: Search
# Needs update: True
#
# Analyzing post: This Week in Data Reading
# Current tags: ['artificial intelligence', 'data exploration', 'Data Science', 'machine learning', 'natural language processing', 'social media']
# Suggested tags: ['data scientist', 'hr analytics']
# Current category: Reading
# Suggested category: Data Science
# Needs update: True
#
# Analyzing post: A Brand Image Analysis of WordPress and Automattic on Twitter
# Current tags: ['influencer marketing', 'social media', 'twitter']
# Suggested tags: ['social media', 'blogging', 'community analysis']
# Current category: Data Science
# Suggested category: Network Science
# Needs update: True
#
# Analyzing post: Bulk Log Analytics With Hive
# Current tags: ['Hadoop', 'Hive']
# Suggested tags: ['analytics', 'blogging', 'data analytics']
# Current category: Data Engineering
# Suggested category: Data Engineering
# Needs update: True
#
# Analyzing post: Evolution of a Plot: Better Data Visualization, One Step at a Time
# Current tags: ['plot']
# Suggested tags: ['Data Visualization', 'graphs']
# Current category: Data Science
# Suggested category: Data Visualization
# Needs update: True
#
# Analyzing post: Network Science at Automattic: Mapping the Communities of WP.com &#8212; Methodology
# Current tags: ['community analysis', 'Data Science']
# Suggested tags: ['community analysis', 'blogging', 'Network Science']
# Current category: Network Science
# Suggested category: Network Science
# Needs update: True
#
# Analyzing post: Intro to Search: Anatomy of a search engine
# Current tags: ['big data', 'Data Science', 'information retrieval', 'search engines']
# Suggested tags: ['search engines', 'information retrieval', 'Semantic Search']
# Current category: Search
# Suggested category: Search
# Needs update: True
#
# Analyzing post: Network Science at Automattic: Mapping the Communities of WP.com
# Current tags: ['community analysis', 'Data Science', 'topic modeling']
# Suggested tags: ['blogging', 'WordPress', 'WordPress.com']
# Current category: Network Science
# Suggested category: Reading
# Needs update: True
#
# Analyzing post: Intro to Search: Initial Considerations
# Current tags: ['big data', 'data analysis', 'Data Science', 'information retrieval']
# Suggested tags: ['search engines', 'information retrieval']
# Current category: Search
# Suggested category: Search
# Needs update: True
#
# Analyzing post: State of WordPress.com Elasticsearch Systems 2016
# Current tags: ['elasticsearch']
# Suggested tags: ['elasticsearch', 'blogging', 'indexing']
# Current category: Data Engineering
# Suggested category: Search
# Needs update: True
#
# Analyzing post: Data for nothing and bytes for free
# Current tags: ['feature engineering', 'missing data']
# Suggested tags: ['blogging', 'WordPress', 'WordPress.org']
# Current category: Data Science
# Suggested category: Search
# Needs update: True
#
# --- Taxonomy Suggestion Statistics ---
# Total posts analyzed: 97
# Unique posts with new suggestions: 95
#
# Top 10 Suggested Tags:
#   data scientist: 13 posts
#   blogging: 11 posts
#   automation: 10 posts
#   hr analytics: 10 posts
#   search engines: 8 posts
#   Data Engineering: 5 posts
#   Semantic Search: 5 posts
#   Latex: 5 posts
#   Data Visualization: 5 posts
#   analytics: 4 posts
#
# Suggested Categories:
#   Network Science: 12 posts
#   Distributed Work: 9 posts
#   Search: 9 posts
#   Data Visualization: 9 posts
#   Reading: 9 posts
#   Data at Automattic: 8 posts
#   Data Engineering: 6 posts
#   Interview: 3 posts
#   Data Science: 3 posts
#   Experimentation Platform: 2 posts

# %%
suggest_taxonomy_improvements(stats, existing_tags, existing_categories)
# Out:
# --- Suggested Taxonomy Improvements ---
#
# Tags that were never suggested (consider removing):
#   Amazon
#   science of work
#   science
#   Top Level Domains
#   bots
#   Git
#   Magenta
#   gender
#   accountability
#   Automattic
#   charts
#   LTSM
#   chess
#   New Year's resolutions
#   gender bias
#   code reviews
#   Donald Trump
#   net neutrality
#   math
#   learning algorithms
#   causal inference
#   fake news
#   critical review
#   influencer marketing
#   hand-drawn graphics
#   pipe
#   work
#   plugin repository
#   Go
#   models
#   retention
#   continuous integration
#   descriptive data analysis
#   Thorsten Dietzsch
#   ethics
#   marketing
#   Honor
#   P2
#   Albert-László Barabási
#   Hans Rosling
#   Conda
#   CircleCI
#   Siraj Raval
#   W.E.B Du Boise
#   network analysis
#   Harry Potter
#   big data
#   marketing science
#   Kevin Ferguson
#   Strava
#   functional programming languages
#   plot
#   security
#   MySQL
#   databases
#   Reddit
#   software architecture
#   pop lyrics
#   twitter
#   Spotify
#   uplift modelling
#   feature engineering
#   Hive
#   Google
#   Java
#   campaign optimisation
#   Christo Wilson
#   Jetpack
#   social science
#   remote work
#   seasonality
#   neural networks
#   interaction
#   bot
#   artificial intelligence
#   data analysis
#   Shaun Lindsay
#   Pinterest
#   Zalando
#   natural language processing
#   analysis
#   telemetry
#   code
#   tooling
#   elasticsearch
#   working conditions
#   p-values
#   statistics
#   time series
#   algorithms
#   bonding
#   SpaceX
#   graph theory
#   Book Club
#   collusion
#   justice
#   algorithm
#   digital minimalism
#   MOOCs
#   covid-19
#   Hadoop
#   Richard Brath
#   anomaly
#   fan fiction
#   meetup
#   topic modeling
#   fairness
#   guest speaker
#   experimentation
#   Desmond Morris
#   Spark
#   human relationships
#   product management
#   data
#   hypotheses-tests
#   API
#   binary classification
#   Ben Orlin
#   coding conventions
#   particle physics
#   machine-made music
#   tables
#   best practices
#
# Overall recommendations:
#   - Consider limiting the total number of tags to 50

# %%
def analyze_taxonomy(posts):
    category_counter = Counter()
    tag_counter = Counter()

    for post in posts:
        category_counter.update([post['suggested_category']])
        tag_counter.update(post['suggested_tags'])

    print("Category usage:")
    for category, count in category_counter.most_common():
        print(f"  {category}: {count}")

    print("\nTag usage:")
    for tag, count in tag_counter.most_common():
        print(f"  {tag}: {count}")

    unused_categories = set(CATEGORIES) - set(category_counter.keys())
    unused_tags = set(TAGS) - set(tag_counter.keys())

    print("\nUnused categories:", unused_categories)
    print("Unused tags:", unused_tags)

# %%
save_posts(posts, 'original_posts.json')

# %%
# Updated taxonomy
CATEGORIES = [
    'Data Engineering', 'Data Science', 'Data Visualization', 'Distributed Work',
    'Experimentation and A/B Testing', 'Network Science', 'Search and Information Retrieval',
    'Machine Learning and AI'
]

TAGS = [
    'Data Science', 'Data Engineering', 'Data Visualization', 'Machine Learning',
    'Artificial Intelligence', 'Distributed Work', 'Remote Work', 'Data Analytics',
    'Tech Industry', 'Communication', 'Productivity', 'Automattic', 'WordPress',
    'Semantic Search', 'Diversity and Inclusion', 'Work-Life Balance', 'Career and Professional Development',
    'Books and Reading', 'Learning and Education', 'Data Discoverability', 'Automation',
    'Software Engineering', 'A/B Testing', 'Experimentation', 'Marketing Analytics',
    'Python', 'Data Speaker Series', 'Scientific Communication', 'Bias in AI', 'Data Ethics',
    'Best Practices', 'Causal Inference', 'Technology Trends',
    'Conferences and Events', 'Transparency in Data', 'Data Retention', 'Network Analysis',
    'Open Source', 'Time Series Analysis', 'Deep Learning', 'Surveys and Research Methods',
    'Data Products', 'Elasticsearch', 'Natural Language Processing', 'Meetup',
    'Information Retrieval', 'Social Media Analytics', 'Feature Engineering', 'Missing Data Handling',
    'Pipe', 'API'
]

# %%
# Load the model
new_model = get_sentence_transformer(model_name='dunzhang/stella_en_1.5B_v5')

# Encode categories and tags once
category_embeddings = new_model.encode(CATEGORIES, convert_to_tensor=True)
tag_embeddings = new_model.encode(TAGS, convert_to_tensor=True)
# Out:
# Downloading and caching model: dunzhang/stella_en_1.5B_v5
# Sliding Window Attention is enabled but not implemented for `sdpa`; unexpected results may be encountered.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# We detected that you are passing `past_key_values` as a tuple and this is deprecated and will be removed in v4.43. Please use an appropriate `Cache` class (https://huggingface.co/docs/transformers/v4.41.3/en/internal/generation_utils#transformers.Cache)

# %%
updated_posts = []
for post in posts:
    # Suggest tags and categories
    suggested_tags, suggested_category = suggest_tags_and_categories(
        post['content'], TAGS, CATEGORIES
    )
    updated_posts.append({
            'ID': post['ID'],
            'title': post['title'],
            'URL': post['URL'],
            'categories': extract_names(post['categories']),
            'tags': extract_names(post['tags']),
            'suggested_category': post['suggested_category'],
            'suggested_tags': post['suggested_tags'],
    })

# %%
def assign_category_and_tags(post_content, num_tags=5):
    # Encode the post content
    post_embedding = model.encode(post_content, convert_to_tensor=True)

    # Find the most similar category
    category_similarities = util.pytorch_cos_sim(post_embedding, category_embeddings)[0]
    best_category_idx = category_similarities.argmax().item()
    assigned_category = CATEGORIES[best_category_idx]

    # Find the most similar tags
    tag_similarities = util.pytorch_cos_sim(post_embedding, tag_embeddings)[0]
    best_tag_idxs = tag_similarities.argsort(descending=True)[:num_tags]
    assigned_tags = [TAGS[idx] for idx in best_tag_idxs]

    return assigned_category, assigned_tags

def process_posts(posts):
    for post in posts:
        content = post['title'] + " " + post['content']  # Combine title and content for better context
        category, tags = assign_category_and_tags(content)
        post['suggested_category'] = category
        post['suggested_tags'] = tags
    return posts

# %%
updated_posts = process_posts(posts)

# %%
for post in updated_posts:
    print(f"Post ID: {post['ID']}")
    print(f"Title: {post['title']}")
    print(f"Suggested Category: {post['suggested_category']}")
    print(f"Suggested Tags: {', '.join(post['suggested_tags'])}")
    print()
# Out:
# Post ID: 3919
# Title: Data Talks &amp; Conferences Recommended by Automatticians
# Suggested Category: Data Science
# Suggested Tags: Conferences and Events, Automattic, Data Science, Automation, Information Retrieval
#
# Post ID: 3862
# Title: What your neurodivergent colleagues wish you knew
# Suggested Category: Network Science
# Suggested Tags: Diversity and Inclusion, Automattic, Bias in AI, Artificial Intelligence, Automation
#
# Post ID: 3856
# Title: From Support to Data Science and Analytics: My Journey at Automattic
# Suggested Category: Data Engineering
# Suggested Tags: Data Analytics, Data Engineering, Feature Engineering, Data Visualization, Automation
#
# Post ID: 3841
# Title: Hack Project: Creating a tool to translate customer feedback into product insights
# Suggested Category: Distributed Work
# Suggested Tags: Distributed Work, Remote Work, Marketing Analytics, Social Media Analytics, Automation
#
# Post ID: 3804
# Title: Hack Project: Tackling FOMO on the P2 Land
# Suggested Category: Network Science
# Suggested Tags: WordPress, Distributed Work, Automation, Open Source, Automattic
#
# Post ID: 3731
# Title: Optimizing Connections at Meetups
# Suggested Category: Distributed Work
# Suggested Tags: Distributed Work, Conferences and Events, Automation, Automattic, Remote Work
#
# Post ID: 3709
# Title: Synchronizing Data with Apache Superset: Our Internal Solution
# Suggested Category: Data Engineering
# Suggested Tags: Data Discoverability, Data Engineering, Automation, Data Visualization, Feature Engineering
#
# Post ID: 3649
# Title: The New Face of Jetpack Stats
# Suggested Category: Data Visualization
# Suggested Tags: Data Visualization, Social Media Analytics, Data Analytics, Marketing Analytics, Feature Engineering
#
# Post ID: 3613
# Title: Quest for Efficient AI: An Evaluation of the Vector Database Landscape
# Suggested Category: Search and Information Retrieval
# Suggested Tags: Semantic Search, Information Retrieval, Data Discoverability, Feature Engineering, Deep Learning
#
# Post ID: 3580
# Title: Visualizing Diversity at Automattic
# Suggested Category: Data Visualization
# Suggested Tags: Diversity and Inclusion, Automattic, Data Visualization, Transparency in Data, Automation
#
# Post ID: 3530
# Title: Tips for a healthy work-life balance for people starting at a remote company
# Suggested Category: Distributed Work
# Suggested Tags: Remote Work, Distributed Work, Work-Life Balance, Best Practices, Productivity
#
# Post ID: 3520
# Title: How to Organize a Data Book Club at Work
# Suggested Category: Search and Information Retrieval
# Suggested Tags: Information Retrieval, Meetup, Books and Reading, Automattic, Machine Learning
#
# Post ID: 3506
# Title: Women of Datamattic | Menaka Sankaralingam
# Suggested Category: Data Visualization
# Suggested Tags: Data Ethics, Elasticsearch, Data Visualization, Data Science, Data Engineering
#
# Post ID: 3494
# Title: Women of Datamattic: Madison Swain-Bowden
# Suggested Category: Data Science
# Suggested Tags: Data Ethics, Elasticsearch, Data Science, Data Engineering, Data Visualization
#
# Post ID: 3464
# Title: Women of Datamattic: Anna Elek
# Suggested Category: Data Science
# Suggested Tags: Data Ethics, Elasticsearch, Data Retention, Data Science, Transparency in Data
#
# Post ID: 3454
# Title: The Data Docs: A WordPress based Data Discoverability Tool
# Suggested Category: Search and Information Retrieval
# Suggested Tags: Data Discoverability, Semantic Search, Information Retrieval, Data Engineering, Elasticsearch
#
# Post ID: 3427
# Title: Stocking Stuffers for the Data Team
# Suggested Category: Search and Information Retrieval
# Suggested Tags: Elasticsearch, Productivity, Information Retrieval, Best Practices, Transparency in Data
#
# Post ID: 3406
# Title: Automattic’s First Data+ Meetup
# Suggested Category: Distributed Work
# Suggested Tags: Distributed Work, Automattic, Automation, Data Discoverability, Data Engineering
#
# Post ID: 3370
# Title: How to Save Time with Alfred, Stream Deck, and Apple Shortcuts
# Suggested Category: Distributed Work
# Suggested Tags: Automation, Work-Life Balance, Automattic, Remote Work, Distributed Work
#
# Post ID: 3342
# Title: How to profit from an Analytics Skill Matrix
# Suggested Category: Distributed Work
# Suggested Tags: Productivity, Marketing Analytics, Data Analytics, Bias in AI, Distributed Work
#
# Post ID: 3227
# Title: Challenge Hiring Assumptions with Data
# Suggested Category: Experimentation and A/B Testing
# Suggested Tags: A/B Testing, Experimentation, Bias in AI, Causal Inference, Surveys and Research Methods
#
# Post ID: 3209
# Title: Advance your Career with Automattic Rotations
# Suggested Category: Data Visualization
# Suggested Tags: Career and Professional Development, Automattic, Work-Life Balance, Automation, Tech Industry
#
# Post ID: 3197
# Title: Join us at Tumblr!
# Suggested Category: Distributed Work
# Suggested Tags: Distributed Work, Remote Work, Diversity and Inclusion, Work-Life Balance, WordPress
#
# Post ID: 3178
# Title: ExPlat’s Development Principles and Practices
# Suggested Category: Distributed Work
# Suggested Tags: Automation, Automattic, Productivity, Distributed Work, Software Engineering
#
# Post ID: 3132
# Title: Architecting ExPlat: Automattic’s New Experimentation Platform
# Suggested Category: Data Engineering
# Suggested Tags: Automation, Automattic, Data Engineering, Experimentation, Software Engineering
#
# Post ID: 3117
# Title: ExPlat: Automattic’s Experimentation Platform
# Suggested Category: Experimentation and A/B Testing
# Suggested Tags: Automation, Automattic, Experimentation, Feature Engineering, Software Engineering
#
# Post ID: 3099
# Title: Being globally distributed: a constant reminder to have an open mind and more
# Suggested Category: Distributed Work
# Suggested Tags: Distributed Work, Work-Life Balance, Remote Work, Technology Trends, Best Practices
#
# Post ID: 3092
# Title: SQL — a Common Language for the Whole Data Team
# Suggested Category: Data Engineering
# Suggested Tags: Data Engineering, Data Science, Data Analytics, Data Discoverability, Elasticsearch
#
# Post ID: 3077
# Title: &#8220;I found a lot of new and exciting ways to break WordPress.com&#8221;: Highlights of our time at Automattic
# Suggested Category: Data Visualization
# Suggested Tags: WordPress, Social Media Analytics, Automattic, Technology Trends, Career and Professional Development
#
# Post ID: 3047
# Title: One Pandemic, Four Countries and Six Different Stories
# Suggested Category: Distributed Work
# Suggested Tags: Technology Trends, Social Media Analytics, Surveys and Research Methods, Diversity and Inclusion, Transparency in Data
#
# Post ID: 3028
# Title: Teaching Python to Beginners
# Suggested Category: Data Science
# Suggested Tags: Python, Learning and Education, Software Engineering, Automation, Data Science
#
# Post ID: 2980
# Title: Five Paths to Automattic
# Suggested Category: Machine Learning and AI
# Suggested Tags: Automattic, Automation, Artificial Intelligence, Social Media Analytics, Career and Professional Development
#
# Post ID: 2959
# Title: Boris Gorelik on the biggest missed opportunity in data visualization
# Suggested Category: Data Visualization
# Suggested Tags: Data Visualization, Data Ethics, Elasticsearch, Data Science, Social Media Analytics
#
# Post ID: 2949
# Title: How to Avoid Statistical Bootstrapping Pitfalls
# Suggested Category: Data Science
# Suggested Tags: Data Discoverability, Data Science, Surveys and Research Methods, Machine Learning, Data Ethics
#
# Post ID: 2928
# Title: Gender and Racial Bias in Cloud NLP Sentiment APIs
# Suggested Category: Search and Information Retrieval
# Suggested Tags: Meetup, Bias in AI, Semantic Search, Social Media Analytics, Diversity and Inclusion
#
# Post ID: 2903
# Title: Christo Wilson Discusses the Ethics of Online Behavioral Experiments
# Suggested Category: Experimentation and A/B Testing
# Suggested Tags: Data Ethics, Experimentation, Surveys and Research Methods, Social Media Analytics, A/B Testing
#
# Post ID: 2859
# Title: Using ML for Campaign Optimization: Our Journey to Marketing Science at Automattic
# Suggested Category: Machine Learning and AI
# Suggested Tags: Machine Learning, Data Science, Automattic, Marketing Analytics, Automation
#
# Post ID: 2846
# Title: Data Science Insights from Cameron Davidson-Pilon
# Suggested Category: Data Science
# Suggested Tags: Python, Data Science, Software Engineering, Data Analytics, Data Engineering
#
# Post ID: 2833
# Title: This Week in Data Reading: Project Estimation, Abandoning Significance, and Video Games.
# Suggested Category: Data Science
# Suggested Tags: Missing Data Handling, Data Retention, Data Ethics, Data Analytics, Data Science
#
# Post ID: 2820
# Title: Looker NYC Meetup
# Suggested Category: Search and Information Retrieval
# Suggested Tags: Semantic Search, Data Discoverability, Information Retrieval, Automation, Open Source
#
# Post ID: 2809
# Title: This Week in Data Reading: Experimentation, Tech and the Humanities, and Eliminating Bias in Testing
# Suggested Category: Data Science
# Suggested Tags: Data Ethics, Data Retention, Transparency in Data, Data Science, Missing Data Handling
#
# Post ID: 2791
# Title: The 2019 Fairness, Accountability, and Transparency Conference
# Suggested Category: Network Science
# Suggested Tags: Data Ethics, Conferences and Events, Diversity and Inclusion, Technology Trends, Transparency in Data
#
# Post ID: 2780
# Title: This Week In Data Reading: MOOCs, Collusion in Artificial Intelligence, and Fake News
# Suggested Category: Data Science
# Suggested Tags: Data Ethics, Transparency in Data, Data Science, Data Retention, Missing Data Handling
#
# Post ID: 2749
# Title: How to Increase Retention and Revenue in 1,000 Nontrivial Steps
# Suggested Category: Data Science
# Suggested Tags: Data Science, Data Engineering, Data Retention, Elasticsearch, Data Analytics
#
# Post ID: 2713
# Title: Building Thousands of Reproducible ML Models with pipe, the Automattic Machine Learning Pipeline
# Suggested Category: Machine Learning and AI
# Suggested Tags: Automation, Feature Engineering, Machine Learning, Automattic, Data Discoverability
#
# Post ID: 2690
# Title: Missed Opportunities for Using Text in Data Visualization
# Suggested Category: Data Visualization
# Suggested Tags: Data Visualization, Data Ethics, Data Science, Social Media Analytics, Data Discoverability
#
# Post ID: 2693
# Title: Links Worth Sharing: What Makes People Successful
# Suggested Category: Data Visualization
# Suggested Tags: Data Ethics, Data Retention, Elasticsearch, Information Retrieval, Data Visualization
#
# Post ID: 2677
# Title: Introducing pipe, The Automattic Machine Learning Pipeline
# Suggested Category: Machine Learning and AI
# Suggested Tags: Automattic, Automation, Deep Learning, Artificial Intelligence, Feature Engineering
#
# Post ID: 2667
# Title: Links Worth Sharing: The Training and Security of Neural Networks
# Suggested Category: Machine Learning and AI
# Suggested Tags: Deep Learning, Machine Learning, Artificial Intelligence, Network Analysis, Data Ethics
#
# Post ID: 2637
# Title: The Most Beautiful Social Network: the Structure of Communication at Automattic
# Suggested Category: Network Science
# Suggested Tags: Communication, Remote Work, Scientific Communication, Distributed Work, Network Analysis
#
# Post ID: 2654
# Title: Conference Recap: EuroSciPy 2018
# Suggested Category: Network Science
# Suggested Tags: Conferences and Events, Scientific Communication, Python, Data Speaker Series, Social Media Analytics
#
# Post ID: 2615
# Title: We&#8217;re Reading About Bandit Algorithms, Binary Classification Problems, and Artificial Intelligence
# Suggested Category: Machine Learning and AI
# Suggested Tags: Information Retrieval, Artificial Intelligence, Bias in AI, Data Ethics, Machine Learning
#
# Post ID: 2597
# Title: Investigating Seasonality in a Time Series: A Mystery in Three Parts
# Suggested Category: Data Visualization
# Suggested Tags: Time Series Analysis, Data Discoverability, Python, Network Analysis, Marketing Analytics
#
# Post ID: 2585
# Title: Reflections From Spark + AI Summit 2018
# Suggested Category: Data Science
# Suggested Tags: Data Speaker Series, Data Science, Elasticsearch, Data Analytics, Data Discoverability
#
# Post ID: 2563
# Title: We&#8217;re Reading About AI, Data Visualization, Deep Learning, and More
# Suggested Category: Data Visualization
# Suggested Tags: Deep Learning, Data Ethics, Data Visualization, Data Retention, Elasticsearch
#
# Post ID: 2538
# Title: This Week We&#8217;re Reading the 2018 Stack Overflow Survey
# Suggested Category: Network Science
# Suggested Tags: Tech Industry, Surveys and Research Methods, Technology Trends, Social Media Analytics, Data Engineering
#
# Post ID: 2514
# Title: Engineering Data Science at Automattic
# Suggested Category: Data Engineering
# Suggested Tags: Data Engineering, Data Science, Feature Engineering, Elasticsearch, Data Visualization
#
# Post ID: 2493
# Title: Data Speaker Series: Kevin Ferguson on AlphaGo Zero
# Suggested Category: Machine Learning and AI
# Suggested Tags: Artificial Intelligence, Bias in AI, Deep Learning, Data Speaker Series, Machine Learning
#
# Post ID: 2483
# Title: This Week We&#8217;re Reading About Artificial Intelligence and Machine Learning
# Suggested Category: Machine Learning and AI
# Suggested Tags: Artificial Intelligence, Data Ethics, Data Retention, Information Retrieval, Machine Learning
#
# Post ID: 2394
# Title: Analysis of A Beautiful Storm: Internal Communication at Automattic
# Suggested Category: Network Science
# Suggested Tags: Communication, Scientific Communication, Network Analysis, Technology Trends, Conferences and Events
#
# Post ID: 2366
# Title: To a Poem is a Bott the Stranger
# Suggested Category: Machine Learning and AI
# Suggested Tags: Artificial Intelligence, Automation, Semantic Search, Meetup, WordPress
#
# Post ID: 2372
# Title: Do New Year&#8217;s Resolutions Work? Data Suggests They Do!
# Suggested Category: Data Engineering
# Suggested Tags: Social Media Analytics, WordPress, Technology Trends, Data Retention, Surveys and Research Methods
#
# Post ID: 2351
# Title: We&#8217;re Reading About Artificially Intelligent Harry Potter Fan Fiction, Verifying Online Identities, and More
# Suggested Category: Data Science
# Suggested Tags: Bias in AI, Data Ethics, Data Retention, Data Science, Transparency in Data
#
# Post ID: 2332
# Title: Doing the Math on Key Words and Top Level Domains
# Suggested Category: Search and Information Retrieval
# Suggested Tags: WordPress, Social Media Analytics, Technology Trends, Semantic Search, Meetup
#
# Post ID: 2320
# Title: We&#8217;re Reading About Simplifying Without Distortion and Adversarial Image Classification
# Suggested Category: Machine Learning and AI
# Suggested Tags: Data Ethics, Transparency in Data, Deep Learning, Bias in AI, Information Retrieval
#
# Post ID: 2254
# Title: Data Speaker Series: Shaun Lindsay on the Data Science of Marketing
# Suggested Category: Data Visualization
# Suggested Tags: Data Speaker Series, Data Ethics, Data Visualization, Elasticsearch, Information Retrieval
#
# Post ID: 2222
# Title: We&#8217;re Reading About Bias in AI, SpaceX, and More
# Suggested Category: Data Science
# Suggested Tags: Bias in AI, Data Ethics, Data Retention, Data Science, Information Retrieval
#
# Post ID: 2163
# Title: Data Speaker Series: Charles Earl on Discriminatory Artificial Intelligence
# Suggested Category: Machine Learning and AI
# Suggested Tags: Bias in AI, Data Speaker Series, Machine Learning, Deep Learning, Artificial Intelligence
#
# Post ID: 1971
# Title: Easier A/B Tests with Automattic’s Own Tool, Hypotheses
# Suggested Category: Experimentation and A/B Testing
# Suggested Tags: A/B Testing, Automation, Automattic, Feature Engineering, Experimentation
#
# Post ID: 1957
# Title: This Week in Data Reading (and Watching!)
# Suggested Category: Data Science
# Suggested Tags: Data Ethics, Elasticsearch, Data Retention, Data Science, Social Media Analytics
#
# Post ID: 1890
# Title: Data Speaker Series: Thorsten Dietzsch on Building Data Products at Zalando
# Suggested Category: Data Science
# Suggested Tags: Data Speaker Series, Elasticsearch, Information Retrieval, Meetup, Data Science
#
# Post ID: 1701
# Title: How Communication Density Fuels Automattic
# Suggested Category: Data Visualization
# Suggested Tags: Scientific Communication, Transparency in Data, Data Visualization, Communication, Automattic
#
# Post ID: 1693
# Title: This Week in Data Reading
# Suggested Category: Data Science
# Suggested Tags: Data Ethics, Data Science, Data Visualization, Data Discoverability, Data Analytics
#
# Post ID: 1578
# Title: Real-Time Elasticsearch Indexing on WordPress.com
# Suggested Category: Search and Information Retrieval
# Suggested Tags: Data Analytics, Social Media Analytics, Semantic Search, Information Retrieval, Data Retention
#
# Post ID: 1486
# Title: data.coalesce() &#8212; Automattic Data Division Meets in Montréal
# Suggested Category: Data Science
# Suggested Tags: Data Retention, Missing Data Handling, Automattic, Automation, Data Analytics
#
# Post ID: 1386
# Title: Time Series Analysis: When “Good Enough” is Good Enough
# Suggested Category: Distributed Work
# Suggested Tags: Data Discoverability, Distributed Work, Automation, Automattic, Time Series Analysis
#
# Post ID: 1391
# Title: This Week in Data Reading
# Suggested Category: Data Science
# Suggested Tags: Data Retention, Information Retrieval, Data Ethics, Missing Data Handling, Data Science
#
# Post ID: 1251
# Title: May the Bot Be With You: How Algorithms are Supporting Happiness at WordPress.com
# Suggested Category: Search and Information Retrieval
# Suggested Tags: Meetup, Artificial Intelligence, Information Retrieval, Semantic Search, Automation
#
# Post ID: 1236
# Title: This Week in Data Reading (and Watching!)
# Suggested Category: Machine Learning and AI
# Suggested Tags: Deep Learning, Books and Reading, Information Retrieval, Artificial Intelligence, Data Ethics
#
# Post ID: 1229
# Title: This Week in Data Reading
# Suggested Category: Data Visualization
# Suggested Tags: Data Ethics, Data Visualization, Transparency in Data, Data Science, Elasticsearch
#
# Post ID: 1173
# Title: Welcoming New Colleagues — a Data-Based Story
# Suggested Category: Data Science
# Suggested Tags: Automattic, Automation, Data Ethics, Tech Industry, Technology Trends
#
# Post ID: 1156
# Title: This Week in Data Reading
# Suggested Category: Data Science
# Suggested Tags: Meetup, Transparency in Data, Data Ethics, Deep Learning, Data Science
#
# Post ID: 934
# Title: Improving Relevance and Elasticsearch Query Patterns
# Suggested Category: Search and Information Retrieval
# Suggested Tags: Semantic Search, Information Retrieval, Data Discoverability, Social Media Analytics, Marketing Analytics
#
# Post ID: 916
# Title: This Week in Data Reading
# Suggested Category: Data Visualization
# Suggested Tags: Data Ethics, Data Visualization, Data Retention, Deep Learning, Data Science
#
# Post ID: 883
# Title: How&#8217;s Your New Year&#8217;s Resolution Going?
# Suggested Category: Search and Information Retrieval
# Suggested Tags: Surveys and Research Methods, Productivity, Social Media Analytics, Work-Life Balance, Data Retention
#
# Post ID: 863
# Title: This Week in Data Reading
# Suggested Category: Data Science
# Suggested Tags: Data Ethics, Data Retention, Transparency in Data, Information Retrieval, Data Science
#
# Post ID: 755
# Title: Intro to Search: Measurement
# Suggested Category: Search and Information Retrieval
# Suggested Tags: Information Retrieval, Semantic Search, Machine Learning, Social Media Analytics, Marketing Analytics
#
# Post ID: 712
# Title: This Week in Data Reading
# Suggested Category: Data Science
# Suggested Tags: Data Science, Data Engineering, Data Ethics, Data Visualization, Elasticsearch
#
# Post ID: 581
# Title: A Brand Image Analysis of WordPress and Automattic on Twitter
# Suggested Category: Network Science
# Suggested Tags: Social Media Analytics, WordPress, Meetup, Marketing Analytics, Scientific Communication
#
# Post ID: 560
# Title: Bulk Log Analytics With Hive
# Suggested Category: Data Engineering
# Suggested Tags: Data Analytics, Data Discoverability, Data Retention, Data Engineering, Marketing Analytics
#
# Post ID: 445
# Title: Evolution of a Plot: Better Data Visualization, One Step at a Time
# Suggested Category: Data Visualization
# Suggested Tags: Data Visualization, Network Analysis, Data Analytics, Social Media Analytics, Transparency in Data
#
# Post ID: 189
# Title: Network Science at Automattic: Mapping the Communities of WP.com &#8212; Methodology
# Suggested Category: Network Science
# Suggested Tags: Network Analysis, WordPress, Social Media Analytics, Distributed Work, Semantic Search
#
# Post ID: 349
# Title: Intro to Search: Anatomy of a search engine
# Suggested Category: Search and Information Retrieval
# Suggested Tags: Information Retrieval, Semantic Search, WordPress, Social Media Analytics, Data Discoverability
#
# Post ID: 115
# Title: Network Science at Automattic: Mapping the Communities of WP.com
# Suggested Category: Network Science
# Suggested Tags: WordPress, Social Media Analytics, Information Retrieval, Open Source, Semantic Search
#
# Post ID: 26
# Title: Intro to Search: Initial Considerations
# Suggested Category: Search and Information Retrieval
# Suggested Tags: Information Retrieval, Semantic Search, WordPress, Social Media Analytics, Books and Reading
#
# Post ID: 170
# Title: State of WordPress.com Elasticsearch Systems 2016
# Suggested Category: Search and Information Retrieval
# Suggested Tags: Semantic Search, Information Retrieval, Social Media Analytics, Natural Language Processing, Data Retention
#
# Post ID: 235
# Title: Data for nothing and bytes for free
# Suggested Category: Search and Information Retrieval
# Suggested Tags: Data Retention, Marketing Analytics, WordPress, Social Media Analytics, Data Analytics

# %%
analyze_taxonomy(updated_posts)
save_posts(updated_posts)
# Out:
# Category usage:
#   Data Science: 22
#   Search and Information Retrieval: 16
#   Data Visualization: 15
#   Machine Learning and AI: 12
#   Distributed Work: 11
#   Network Science: 10
#   Data Engineering: 7
#   Experimentation and A/B Testing: 4
#
# Tag usage:
#   Data Ethics: 30
#   Data Science: 28
#   Automation: 26
#   Social Media Analytics: 26
#   Information Retrieval: 24
#   Automattic: 22
#   Data Retention: 21
#   Data Visualization: 18
#   Elasticsearch: 17
#   Data Discoverability: 16
#   Semantic Search: 15
#   Data Analytics: 14
#   Data Engineering: 14
#   Transparency in Data: 14
#   Distributed Work: 13
#   WordPress: 12
#   Artificial Intelligence: 11
#   Bias in AI: 10
#   Marketing Analytics: 10
#   Deep Learning: 10
#   Machine Learning: 10
#   Feature Engineering: 9
#   Technology Trends: 9
#   Meetup: 8
#   Remote Work: 7
#   Surveys and Research Methods: 7
#   Diversity and Inclusion: 6
#   Work-Life Balance: 6
#   Network Analysis: 6
#   Data Speaker Series: 6
#   Conferences and Events: 5
#   Productivity: 5
#   Experimentation: 5
#   Software Engineering: 5
#   Missing Data Handling: 5
#   Scientific Communication: 5
#   Python: 4
#   Open Source: 3
#   Best Practices: 3
#   Books and Reading: 3
#   A/B Testing: 3
#   Career and Professional Development: 3
#   Tech Industry: 3
#   Communication: 3
#   Time Series Analysis: 2
#   Causal Inference: 1
#   Learning and Education: 1
#   Natural Language Processing: 1
#
# Unused categories: set()
# Unused tags: {'Pipe', 'Data Products', 'API'}
